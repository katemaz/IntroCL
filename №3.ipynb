# %% [markdown]
# #3
# 1. r"([a-zA-Z0-9_-]+)@([a-z]+\.[a-z]{2,})"
#
# 2. r"([a-zA-Z]:\\|\/)?([^\/\\\0]+[\/\\])*[^\/\\\0]+$"
#
# 3. 1) для поиска сем. роли r"\[\s*(\w+):"
# 2) словоформы r"([^"]+)"
# 3) леммы
# 4) лексического класса r":([^":]+):"
# 5) семантического класса
